# %%
import numpy as np

# %%
A = np.array([
    [3, 7],
    [-4, -6],
    [7, 8],
    [1, -1],
    [-4, -1],
    [-3, -7]
])

# %%
A
# Out:
# array([[ 3,  7],
#        [-4, -6],
#        [ 7,  8],
#        [ 1, -1],
#        [-4, -1],
#        [-3, -7]])

# %%
A.shape
# Out:
# (6, 2)

# %%
import pandas as pd

# %%
pd.DataFrame(A)
# Out:
#    0  1
# 0  3  7
# 1 -4 -6
# 2  7  8
# 3  1 -1
# 4 -4 -1
# 5 -3 -7

# %%
# GIVE column names

df = pd.DataFrame(A, columns=['a0' , 'a1'])

# %%
df

#here mean is zero for both a0 and a1 .so both columns are having mean 0 and std dev
# = 1. so no need to convert the data into std normal dis
# Out:
#    a0  a1
# 0   3   7
# 1  -4  -6
# 2   7   8
# 3   1  -1
# 4  -4  -1
# 5  -3  -7

# %% [markdown]
# here we have to find the covar between a0 and a1 how change in one column
# is affecting the change in another column

# %%
a0 = A[:, 0]  # ALL THE ROWS, 0TH COLUMN
a1 = A[:, 1]  # ALL THE ROWS, FIRST COLIMN

# %%
a0
# Out:
# array([ 3, -4,  7,  1, -4, -3])

# %%
a1
# Out:
# array([ 7, -6,  8, -1, -1, -7])

# %%
np.cov(a0, a1)
# Out:
# array([[20., 25.],
#        [25., 40.]])

# %%
np.sum(a0*a1)/5  # covar = 25
# Out:
# 25.0

# %%
# 3rd way to find the covar. transpose A matirx

# %%
A.T
# Out:
# array([[ 3, -4,  7,  1, -4, -3],
#        [ 7, -6,  8, -1, -1, -7]])

# %%
A.T @ A/5  # @ IS USED For matrix multiplication
# Out:
# array([[20., 25.],
#        [25., 40.]])

# %%
# eigen value , eigen vector

# %%
sigma = A.T @ A/5

# %%
np.linalg.eig(sigma)
# Out:
# (array([ 3.07417596, 56.92582404]),
#  array([[-0.82806723, -0.56062881],
#         [ 0.56062881, -0.82806723]]))

# %%
l, x = np.linalg.eig(sigma)

# %%
l
# Out:
# array([ 3.07417596, 56.92582404])

# %%
x
# Out:
# array([[-0.82806723, -0.56062881],
#        [ 0.56062881, -0.82806723]])

# %%
sigma
# Out:
# array([[20., 25.],
#        [25., 40.]])

# %%
sigma @ x[:, 0]
# Out:
# array([-2.54562438,  1.72347161])

# %%
sigma @ x[:,1]
# Out:
# array([-31.91425695, -47.13840945])

# %%
print("first principal component")

x[:,1]
# Out:
# first principal component
# array([-0.56062881, -0.82806723])

# %%
print("second principal component")

x[:,0]
# Out:
# second principal component
# array([-0.82806723,  0.56062881])

# %%
A # WE HAVE THE PRICNIPAL  COMPONENT .  we have to rotate the pc1 in such a way that
# it will behave as a x axis, then only we can say it is a first pricipal
# component , for that we need to multiply matrix with first pca value
# Out:
# array([[ 3,  7],
#        [-4, -6],
#        [ 7,  8],
#        [ 1, -1],
#        [-4, -1],
#        [-3, -7]])

# %%
A @ x[:,1] # below is the  pc1 values
# Out:
# array([ -7.47835704,   7.21091862, -10.54893951,   0.26743842,
#          3.07058247,   7.47835704])

# %%
pc1_arr = A @ x[:,1]

# %%
pc1_arr
# Out:
# array([ -7.47835704,   7.21091862, -10.54893951,   0.26743842,
#          3.07058247,   7.47835704])

# %%
pc2_arr = A @ x[:,0]

# %%
pc2_arr
# Out:
# array([ 1.44019997, -0.05150393, -1.31144014, -1.38869604,  2.75164011,
#        -1.44019997])

# %%
df = pd.read_csv(r"D:\My Downloads\glass.data" )

# %%
df
# Out:
#       sl       RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
df = df.drop(columns = ['sl' , 'Class'])

# %%
df
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
df.describe()
# Out:
#                RI          Na          Mg          AI          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %% [markdown]
# avg is not = to zero and std dev is not eq to 1. in order to implement PCA , the data needs to be in Std normal dist.
# So we need to standardize the data, convert  the data into std normal dist

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df_scaled
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
pd.DataFrame(df_scaled)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#             7         8
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
df1 = df_scaled

# %%
df1.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-784441b173b6> in <module>
# ----> 1 df1.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
df1 = pd.DataFrame(df_scaled)

# %%
df1.describe() 
# now mean is 0 and std dev is 1. now we can apply PCA on this dataset
# Out:
#                   0             1             2             3             4  \
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# mean  -2.737478e-14  2.179980e-15 -2.801497e-16 -3.434428e-16  9.966067e-16
# std    1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00
# min   -2.381516e+00 -3.286943e+00 -1.865511e+00 -2.318616e+00 -3.676472e+00
# 25%   -6.082728e-01 -6.141580e-01 -3.957744e-01 -5.117560e-01 -4.800288e-01
# 50%   -2.262293e-01 -1.323817e-01  5.527787e-01 -1.704602e-01  1.799655e-01
# 75%    2.614331e-01  5.120326e-01  6.361680e-01  3.715977e-01  5.649621e-01
# max    5.137232e+00  4.875637e+00  1.254639e+00  4.125851e+00  3.570524e+00
#
#                   5             6             7             8
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# mean   7.470660e-17 -3.137418e-16 -1.763906e-16 -6.121791e-17
# std    1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00
# ...

# %% [markdown]
# next we need to find the relationship using covariance, then eigen vectores

# %%
sigma = np.cov(df_scaled)

# %%
sigma
# Out:
# array([[ 0.61967223,  0.1554839 ,  0.0095123 , ..., -0.36961439,
#         -0.55499756, -0.52499357],
#        [ 0.1554839 ,  0.23446913,  0.20927571, ..., -0.10528676,
#         -0.06703188, -0.11242412],
#        [ 0.0095123 ,  0.20927571,  0.26700812, ..., -0.07709654,
#          0.03531121, -0.01133884],
#        ...,
#        [-0.36961439, -0.10528676, -0.07709654, ...,  2.02504465,
#          1.91941657,  1.96842824],
#        [-0.55499756, -0.06703188,  0.03531121, ...,  1.91941657,
#          2.03457864,  2.03557203],
#        [-0.52499357, -0.11242412, -0.01133884, ...,  1.96842824,
#          2.03557203,  2.07393387]])

# %% [markdown]
# now we have to find out eigen value and eigen vecotr by passing sigma

# %%
l , x = np.linalg.eig(sigma)

# %%
l  # actually we should get egen values eqaul to total no of x features. but here we are seeing more.
# Out:
# array([ 6.71592738e+01+0.00000000e+00j,  5.22063997e+01+0.00000000e+00j,
#         3.61289031e+01+0.00000000e+00j,  3.08518650e+01+0.00000000e+00j,
#         2.20284946e+01+0.00000000e+00j,  1.41097180e+01+0.00000000e+00j,
#         9.67342811e+00+0.00000000e+00j,  1.37509003e+00+0.00000000e+00j,
#        -1.34350462e-15+4.38058739e-15j, -1.34350462e-15-4.38058739e-15j,
#        -2.52567306e-15+3.66836862e-15j, -2.52567306e-15-3.66836862e-15j,
#        -4.17968466e-15+0.00000000e+00j, -3.74622039e-15+1.42333981e-15j,
#        -3.74622039e-15-1.42333981e-15j,  4.46415842e-15+0.00000000e+00j,
#         1.78949166e-15+3.52463284e-15j,  1.78949166e-15-3.52463284e-15j,
#         4.02413643e-15+0.00000000e+00j,  3.33676657e-15+2.16323448e-15j,
#         3.33676657e-15-2.16323448e-15j, -1.43720005e-16+3.74683255e-15j,
#        -1.43720005e-16-3.74683255e-15j,  3.07568657e-15+1.71153801e-15j,
#         3.07568657e-15-1.71153801e-15j, -2.97935947e-15+1.29390018e-15j,
# ...

# %% [markdown]
# so lets calculate eigen values manually

# %%
df_scaled . T @ df_scaled/213  #(213 = no of rows)
# Out:
# array([[ 1.00469484e+00, -1.92786249e-01, -1.22848096e-01,
#         -4.09238363e-01, -5.44597046e-01, -2.91193428e-01,
#          8.14207404e-01, -3.87831208e-04,  1.43681016e-01],
#        [-1.92786249e-01,  1.00469484e+00, -2.75017087e-01,
#          1.57529788e-01, -7.01365474e-02, -2.67335737e-01,
#         -2.76735643e-01,  3.28136226e-01, -2.42479493e-01],
#        [-1.22848096e-01, -2.75017087e-01,  1.00469484e+00,
#         -4.84060474e-01, -1.66705721e-01,  5.42099905e-03,
#         -4.45833360e-01, -4.94573208e-01,  8.34494798e-02],
#        [-4.09238363e-01,  1.57529788e-01, -4.84060474e-01,
#          1.00469484e+00, -5.54965338e-03,  3.27488767e-01,
#         -2.60810752e-01,  4.81654624e-01, -7.47514567e-02],
#        [-5.44597046e-01, -7.01365474e-02, -1.66705721e-01,
#         -5.54965338e-03,  1.00469484e+00, -1.94238511e-01,
#         -2.09712117e-01, -1.02630894e-01, -9.46429875e-02],
#        [-2.91193428e-01, -2.67335737e-01,  5.42099905e-03,
# ...

# %%
l , x = np.linalg.eig(df_scaled . T @ df_scaled/213)

# %%
l # so now we got 9 eigne values
# Out:
# array([2.52295323e+00, 2.05969694e+00, 1.41143951e+00, 1.16329842e+00,
#        9.18293337e-01, 5.30112353e-01, 3.70690643e-01, 6.41527269e-02,
#        1.61637096e-03])

# %%
x
# Out:
# array([[-0.54517662,  0.28568318,  0.08691083, -0.14738099,  0.0735427 ,
#         -0.11528772, -0.08186724, -0.7522159 ,  0.02573194],
#        [ 0.2581256 ,  0.27035007, -0.38491962, -0.49124204, -0.1536833 ,
#          0.55811757, -0.14858006, -0.12769315, -0.31193718],
#        [-0.11088095, -0.59355826,  0.00841796, -0.37878577, -0.12350912,
#         -0.30818598,  0.20604537, -0.07689061, -0.57727335],
#        [ 0.42870863,  0.29521154,  0.32923712,  0.13750592, -0.01410888,
#          0.01885731,  0.69923557, -0.27444105, -0.19222686],
#        [ 0.22883635, -0.15509891, -0.45870884,  0.65253771, -0.00850012,
#         -0.08609797, -0.21606658, -0.37992298, -0.29807321],
#        [ 0.21934405, -0.15397013,  0.66257412,  0.03853544,  0.30703984,
#          0.24363237, -0.50412141, -0.10981168, -0.26050863],
#        [-0.49230609,  0.3453798 , -0.00098473,  0.27644322,  0.18818774,
#          0.14866937,  0.09913463,  0.39870468, -0.57932321],
# ...

# %% [markdown]
# we have to select the highest eigen value as PC1 principal component 1 . To calculate PC1, we need to muliply highest eigen value with first x value. ie, all rows from 0th column

# %%
pc1_data = df_scaled @ x[:,0]

# %%
pc1_data
# Out:
# array([-1.15113957e+00,  5.74137172e-01,  9.40159722e-01,  1.42083283e-01,
#         3.51092291e-01,  2.90266583e-01,  2.52671444e-01,  1.20299466e-01,
#         2.08160308e-02,  2.35222894e-03,  3.82514937e-01,  1.33538675e-02,
#         3.09724390e-01, -1.56521013e-01,  8.99566628e-02,  1.15255023e-01,
#        -1.73458320e-01, -1.45812372e+00, -5.47316267e-01,  3.08817022e-01,
#        -2.05673879e-01, -1.21605345e+00, -4.11679297e-02,  1.13206012e-01,
#         1.47523366e-01,  5.04865218e-02,  1.55773980e-01,  2.17093779e-01,
#         1.15093633e-01,  6.58374915e-02, -2.98261451e-01,  2.22363433e-02,
#        -3.96586112e-01,  6.90862734e-02, -8.17537725e-02,  3.88918640e-01,
#        -2.57422809e-01, -2.70430953e-02, -1.93311245e+00, -1.93311245e+00,
#        -2.13978802e-01, -1.73653764e-02,  9.91042449e-02, -1.90784649e+00,
#        -7.55238909e-01, -4.15149070e-01, -6.04423395e-01, -2.97136159e+00,
# ...

# %%
pc1_data.shape
# Out:
# (214,)

# %%
pc2_data = df_scaled @ x[:,1]

# %%
pc2_data
# Out:
# array([-0.52948764, -0.75978777, -0.92983597, -0.96167744, -1.09124921,
#        -1.32400756, -1.11614958, -1.22184622, -0.32193261, -1.06581344,
#        -1.38013403, -1.10471913, -1.42304024, -1.23592823, -1.18125211,
#        -1.16028212, -1.18243967,  0.09884138, -0.29566013, -0.76316216,
#        -0.99918266, -0.43689611, -1.02788338, -1.02762181, -0.93376705,
#        -1.04723075, -0.73814955, -1.03946718, -1.05293936, -0.90287584,
#        -1.16489328, -1.16273745, -1.07307343, -1.16390421, -0.96601943,
#        -1.00978004, -0.09893604, -0.94115087, -0.1421143 , -0.1421143 ,
#        -1.06505169, -1.10093167, -0.74680692, -0.13514622, -1.19430193,
#        -0.29328726, -0.78019985,  0.4631405 , -0.19367388, -0.34025819,
#        -0.11303858, -0.47489193, -0.41450604, -0.4099579 , -0.51028779,
#        -0.97207179, -1.81655603, -0.95745406, -1.10236197, -1.05432062,
#        -0.5519114 ,  0.5683302 , -0.2964757 ,  0.18518682, -0.23485117,
# ...

# %% [markdown]
# lets validiate above manual pca's generated with sklearn pca algo

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
pca.fit_transform(df1)
# Out:
# array([[ 1.15113957e+00, -5.29487638e-01],
#        [-5.74137172e-01, -7.59787774e-01],
#        [-9.40159722e-01, -9.29835966e-01],
#        [-1.42083283e-01, -9.61677440e-01],
#        [-3.51092291e-01, -1.09124921e+00],
#        [-2.90266583e-01, -1.32400756e+00],
#        [-2.52671444e-01, -1.11614958e+00],
#        [-1.20299466e-01, -1.22184622e+00],
#        [-2.08160308e-02, -3.21932609e-01],
#        [-2.35222894e-03, -1.06581344e+00],
#        [-3.82514937e-01, -1.38013403e+00],
#        [-1.33538675e-02, -1.10471913e+00],
#        [-3.09724390e-01, -1.42304024e+00],
#        [ 1.56521013e-01, -1.23592823e+00],
#        [-8.99566628e-02, -1.18125211e+00],
#        [-1.15255023e-01, -1.16028212e+00],
#        [ 1.73458320e-01, -1.18243967e+00],
#        [ 1.45812372e+00,  9.88413780e-02],
#        [ 5.47316267e-01, -2.95660130e-01],
#        [-3.08817022e-01, -7.63162157e-01],
#        [ 2.05673879e-01, -9.99182661e-01],
#        [ 1.21605345e+00, -4.36896108e-01],
# ...

# %% [markdown]
# so we can generate n no of pca's when the dataset has n features. but how to identify how many pca's actaully we need?
# for that we use expalined variance ration

# %%
import matplotlib.pyplot as plt
pca = PCA()

# %%
principal_cmponent = pca.fit_transform(df1)

# %%
plt.figure()

# %%
pca.explained_variance_ratio_
# Out:
# array([2.79018192e-01, 2.27785798e-01, 1.56093777e-01, 1.28651383e-01,
#        1.01555805e-01, 5.86261325e-02, 4.09953826e-02, 7.09477197e-03,
#        1.78757536e-04])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("number of required components")
plt.ylabel("eVR")
# Out:
# Text(0, 0.5, 'eVR')

# %%
pca.explained_variance_ratio_
# Out:
# array([2.79018192e-01, 2.27785798e-01, 1.56093777e-01, 1.28651383e-01,
#        1.01555805e-01, 5.86261325e-02, 4.09953826e-02, 7.09477197e-03,
#        1.78757536e-04])

# %% [markdown]
# from the graph we can see that,by using 5/6 pcomponents we are able to explain morethan 90% of original data.
# totally we have 9 columns, if we go by pca and use only 5 pca , we will be able to get  whole meaning of the dataset
# or morethan 90% of data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"D:\My Downloads\glass.data")

# %%
data
# Out:
#       sl       RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
# check for null values

data.isna().sum()
# Out:
# sl       0
# RI       0
# Na       0
# Mg       0
# AI       0
# Si       0
# K        0
# Ca       0
# Ba       0
# Fe       0
# Class    0
# dtype: int64

# %%
# we can apply pca only on feature columns, not on label. so lets drop the label

data = data.drop(columns = ['sl' ,'Class'])

# %%
data
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %% [markdown]
#   first rule in pca is to make sure that the dataset is having mean =0 and std dev = 1 or not. then only we can
# decompone features

# %%
data.describe()
# Out:
#                RI          Na          Mg          AI          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %% [markdown]
# mean is not = 0 and std dev not = 1. so we need to convert the data into std normal dist

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit_transform(data)
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %% [markdown]
# covert the above data into dataframe

# %%
scaled_data = scaler.fit_transform(data)

# %%
df = pd.DataFrame(scaled_data, columns = data.columns)

# %%
df
# Out:
#            RI        Na        Mg        AI        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
df.describe()

# we can see now mean =0 and std dev = 1
# Out:
#                  RI            Na            Mg            AI            Si  \
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# mean  -2.737478e-14  2.179980e-15 -2.801497e-16 -3.434428e-16  9.966067e-16
# std    1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00
# min   -2.381516e+00 -3.286943e+00 -1.865511e+00 -2.318616e+00 -3.676472e+00
# 25%   -6.082728e-01 -6.141580e-01 -3.957744e-01 -5.117560e-01 -4.800288e-01
# 50%   -2.262293e-01 -1.323817e-01  5.527787e-01 -1.704602e-01  1.799655e-01
# 75%    2.614331e-01  5.120326e-01  6.361680e-01  3.715977e-01  5.649621e-01
# max    5.137232e+00  4.875637e+00  1.254639e+00  4.125851e+00  3.570524e+00
#
#                   K            Ca            Ba            Fe
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# mean   7.470660e-17 -3.137418e-16 -1.763906e-16 -6.121791e-17
# std    1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00
# ...

# %% [markdown]
# next we need to find the relationship/covar matrix, then we need to find the eigen value and egen vecotr.
# after finding eigen values and eigen vector, whichever is having the highest eigen value so we have to take that eigen
# vector and we suppose to do a matrix multiplication with the above dataset. In this way we will be able to generate the
# first pricipal component.
# IF we want to generate the 2nd pca, then we have to consider the second highest eigen value and its respective eigen vector
# then we need to matrix multiply that vector with above whole dataset
# so we should be  able to generate total n number of pca's where n is the no of features available in the dataset
# but there is no need to generating the n no of pca's as n no of columns are not going to give you equal significance.
# so  we are looking for the dataset which retains a 90% property of the original dataset. The new dataset we are going to
# dervie with the help of pca such that it contains 90% property of original dataset.
# SO how to identify how many pca's we need that will represent 90% property of original data? that we will do with the help
# fo explain variance ratio. we can draw the stream plot with the help of explain variance ratio, then our work will be done
#
# so lets use both manual and library way's to do the calculations, so that we can verify whatever cals we doing are in sync or not

# %%
from sklearn.decomposition  import PCA
pca = PCA()
pca.fit_transform(df)
# Out:
# array([[ 1.15113957, -0.52948764, -0.37209565, ..., -0.39560005,
#         -0.19716008,  0.01634649],
#        [-0.57413717, -0.75978777, -0.55670817, ..., -0.02415793,
#         -0.28421356, -0.0107898 ],
#        [-0.94015972, -0.92983597, -0.55490744, ..., -0.36751757,
#         -0.09594067,  0.02164019],
#        ...,
#        [-1.68024627,  3.28482346, -0.93034851, ...,  0.67412231,
#         -0.89170969,  0.04628358],
#        [-2.36974768,  2.7568728 , -1.23470076, ...,  0.67889932,
#          0.07446015, -0.02730068],
#        [-2.26264885,  3.02859155, -0.89084474, ...,  0.46246107,
#          0.0633149 , -0.01944978]])

# %%
pca.explained_variance_ratio_
# Out:
# array([2.79018192e-01, 2.27785798e-01, 1.56093777e-01, 1.28651383e-01,
#        1.01555805e-01, 5.86261325e-02, 4.09953826e-02, 7.09477197e-03,
#        1.78757536e-04])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("no of columns")
plt.ylabel("EVR")
# Out:
# Text(0, 0.5, 'EVR')

# %%
pd.DataFrame(pca.fit_transform(df)) # by default it will generate n no of pca's. n = no of features.

# but we don't need n no of pca's as our plan is to see reduction in dimensionality, so how many pca's we need, that we
# can decide by using explain varience ratio,by looking at the stream graph and see for how many pca's it will retain 90%
# original data.
# FROM the above graph we can we need around 5/6 pca's that will retain 99.
# from 4 no of pca's we will be able to generate 80% of original data. lets calculate n=5 no of pca's
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.151140 -0.529488 -0.372096  1.728901 -0.251936  0.340210 -0.395600
# 1   -0.574137 -0.759788 -0.556708  0.760232 -0.257071 -0.115960 -0.024158
# 2   -0.940160 -0.929836 -0.554907  0.206254 -0.237506  0.126630 -0.367518
# 3   -0.142083 -0.961677 -0.117125  0.415724 -0.476299  0.285805 -0.052497
# 4   -0.351092 -1.091249 -0.485079  0.069102 -0.432090  0.298032  0.158570
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -2.383835  3.061677  0.090445 -0.376611  0.103227  0.231162 -1.320186
# 210 -2.397652  3.108236 -1.117502  0.288454  0.624723  0.618056  0.582361
# 211 -1.680246  3.284823 -0.930349 -0.171014  0.451687  1.247320  0.674122
# 212 -2.369748  2.756873 -1.234701 -0.525285  0.515008  1.003352  0.678899
# 213 -2.262649  3.028592 -0.890845 -0.414491  0.505474  1.213617  0.462461
#
#             7         8
# 0   -0.197160  0.016346
# 1   -0.284214 -0.010790
# ...

# %%
pca1 = PCA(n_components=5)

# %%
new_data = pca1.fit_transform(df)

# %%
new_data
# Out:
# array([[ 1.15113957, -0.52948764, -0.37209565,  1.72890103, -0.25193583],
#        [-0.57413717, -0.75978777, -0.55670817,  0.76023228, -0.25707069],
#        [-0.94015972, -0.92983597, -0.55490744,  0.20625431, -0.23750587],
#        ...,
#        [-1.68024627,  3.28482346, -0.93034851, -0.17101386,  0.45168739],
#        [-2.36974768,  2.7568728 , -1.23470076, -0.52528451,  0.51500795],
#        [-2.26264885,  3.02859155, -0.89084474, -0.41449108,  0.50547398]])

# %%
pd.DataFrame(new_data, columns = ['PC1' , 'PC2' , 'PC3' , 'PC4' , 'PC5'])
# Out:
#           PC1       PC2       PC3       PC4       PC5
# 0    1.151140 -0.529488 -0.372096  1.728901 -0.251936
# 1   -0.574137 -0.759788 -0.556708  0.760232 -0.257071
# 2   -0.940160 -0.929836 -0.554907  0.206254 -0.237506
# 3   -0.142083 -0.961677 -0.117125  0.415724 -0.476299
# 4   -0.351092 -1.091249 -0.485079  0.069102 -0.432090
# ..        ...       ...       ...       ...       ...
# 209 -2.383835  3.061677  0.090445 -0.376611  0.103227
# 210 -2.397652  3.108236 -1.117502  0.288454  0.624723
# 211 -1.680246  3.284823 -0.930349 -0.171014  0.451687
# 212 -2.369748  2.756873 -1.234701 -0.525285  0.515008
# 213 -2.262649  3.028592 -0.890845 -0.414491  0.505474
#
# [214 rows x 5 columns]

# %%
# ORIGINAL dataset has 9 columns/features, with PCA we have 5 columns that is representing 90% original data. 
# so now pc1 to pc5 will become x(features).like this we reduced the complexity of the input features from 9 to 5 columns.
# now we can apply any cliassifier on this dataset

data
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
# lets build one classifier by taking pc1 to pc5 as x features and take label from original dataset as y

data1 = pd.read_csv(r"D:\My Downloads\glass.data")

# %%
y = data1.Class

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Class, Length: 214, dtype: int64

# %%
x= pd.DataFrame(new_data, columns = ['PC1' , 'PC2' , 'PC3' , 'PC4' , 'PC5'])

# %%
x
# Out:
#           PC1       PC2       PC3       PC4       PC5
# 0    1.151140 -0.529488 -0.372096  1.728901 -0.251936
# 1   -0.574137 -0.759788 -0.556708  0.760232 -0.257071
# 2   -0.940160 -0.929836 -0.554907  0.206254 -0.237506
# 3   -0.142083 -0.961677 -0.117125  0.415724 -0.476299
# 4   -0.351092 -1.091249 -0.485079  0.069102 -0.432090
# ..        ...       ...       ...       ...       ...
# 209 -2.383835  3.061677  0.090445 -0.376611  0.103227
# 210 -2.397652  3.108236 -1.117502  0.288454  0.624723
# 211 -1.680246  3.284823 -0.930349 -0.171014  0.451687
# 212 -2.369748  2.756873 -1.234701 -0.525285  0.515008
# 213 -2.262649  3.028592 -0.890845 -0.414491  0.505474
#
# [214 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
# original data set is as below

data1
# Out:
#       sl       RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
# user who is using this model will not be aware that if I am using PCA internally. he will provide all the 9 values 
# during prediction. 
# we need to pass user provoided data to pca1

# %%
 pca1.transform([[ 1.52101, 13.64,4.49,1.10,71.78, 0.06, 8.75, 0.00, 0.0]])
# Out:
# array([[-14.79669374,  -6.33840708, -37.61313627, -40.78614602,
#           1.49953006]])

# %%
dt_model.predict( pca1.transform([[ 1.52101, 13.64,4.49,1.10,71.78, 0.06, 8.75, 0.00, 0.0]]))
# Out:
# array([5], dtype=int64)

# %%
# manual calculation of pca

def pc_calc(x,no):
    pca = {}
    scaler = StandardScaler()
    x_scaled = scaler.fit_transform(x)
    l,x = np.linalg.eig((x_scaled.T @ x_scaled)/(x_scaled.shape[0]-1))
    for i in range(no):
        pc = x_scaled @ x[:,i]
        pca[i] = pc
    pca_df = pd.DataFrame(pca)
    return pca_df
